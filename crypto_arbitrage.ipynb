# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters
bitstamp = pd.read_csv(
    Path('Resources/bitstamp.csv'),
    index_col="Timestamp", 
    parse_dates=True, 
    infer_datetime_format=True
    )

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head function to confirm that the data was imported properly.
bitstamp.head()
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %%
# Use the tail function to confirm that the data was imported properly.
bitstamp.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6935.01  6939.07  6922.56  $6922.56    1.044354
# 2018-03-31 23:56:00  6922.02  6922.02  6918.00  $6920.32    3.069539
# 2018-03-31 23:57:00  6920.33  6936.42  6920.33  $6934.72   28.239049
# 2018-03-31 23:58:00  6927.65  6929.42  6927.65  $6927.65    0.839507
# 2018-03-31 23:59:00  6929.98  6929.98  6928.00  $6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00    7240.034602     6932.550078
# 2018-03-31 23:56:00   21245.076275     6921.260233
# 2018-03-31 23:57:00  195789.408220     6933.286106
# 2018-03-31 23:58:00    5817.007705     6929.080007
# 2018-03-31 23:59:00    1450.735763     6929.289993

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters
coinbase = pd.read_csv(
    Path('Resources/coinbase.csv'),
    index_col="Timestamp", 
    parse_dates=True, 
    infer_datetime_format=True
    )

# %%
# Use the head function to confirm that the data was imported properly.
coinbase.head()
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %%
# Use the tail function to confirm that the data was imported properly.
coinbase.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6945.20  6948.06  6930.00   $6930.0    5.802288
# 2018-03-31 23:56:00  6930.00  6930.01  6930.00  $6930.01    0.625053
# 2018-03-31 23:57:00  6930.01  6933.91  6930.01  $6933.91    0.776431
# 2018-03-31 23:58:00  6933.91  6938.00  6933.90  $6937.31    0.133413
# 2018-03-31 23:59:00  6937.30  6937.30  6931.09   $6934.0    1.012720
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00  40243.918480     6935.869979
# 2018-03-31 23:56:00   4331.620701     6930.005567
# 2018-03-31 23:57:00   5382.532162     6932.405747
# 2018-03-31 23:58:00    925.356547     6936.048538
# 2018-03-31 23:59:00   7022.275088     6934.070316

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame
# first see how many records in the DataFrame
bitstamp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 129540 entries, 2018-01-01 00:00:00 to 2018-03-31 23:59:00
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Open            129067 non-null  float64
#  1   High            129067 non-null  float64
#  2   Low             129067 non-null  float64
#  3   Close           129540 non-null  object
#  4   BTC Volume      129067 non-null  float64
#  5   USD Volume      129067 non-null  float64
#  6   Weighted Price  129067 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 7.9+ MB

# %%
# see if there are null values
bitstamp.isnull().sum()
# Out:
# Open              473
# High              473
# Low               473
# Close               0
# BTC Volume        473
# USD Volume        473
# Weighted Price    473
# dtype: int64

# %% [markdown]
# #### Null assessment of bitstamp DataFrame
# Only 473 records out of 129540 records have null values. Since the number of such records is very small, these records will be dropped.

# %%
# drop null values out of bitstamp dataFrame
bitstamp = bitstamp.dropna()
# confirm null records have been dropped
bitstamp.isnull().sum()
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# first examine bitstamp DataFrame data types
bitstamp.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close              object
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ##### Close column is not numeric.  It contains a `$` character.

# %%
# Use the str.replace function to remove the dollar sign, $
bitstamp.loc[:, "Close"] = bitstamp.loc[:, "Close"].str.replace("$", "")
# confirm that 4 was removed
bitstamp.head()
# Out:
# /Users/martinsmith/opt/anaconda3/envs/cryptage/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# ...

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
bitstamp.loc[:, "Close"] = bitstamp.loc[:, "Close"].astype("float")
# confirm type of Close changed to float
bitstamp.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary
bitstamp.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### There are no duplicated records to remove from the bitstamp DataFrame.

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Repeat Steps 1–4 for the coinbase DataFrame
# For the coinbase DataFrame, replace or drop all NaNs or missing values in the DataFrame
# first see how many records in the DataFrame
coinbase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 129540 entries, 2018-01-01 00:00:00 to 2018-03-31 23:59:00
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Open            129322 non-null  float64
#  1   High            129322 non-null  float64
#  2   Low             129322 non-null  float64
#  3   Close           129540 non-null  object
#  4   BTC Volume      129322 non-null  float64
#  5   USD Volume      129322 non-null  float64
#  6   Weighted Price  129322 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 7.9+ MB

# %%
# see if there are null values
coinbase.isnull().sum()
# Out:
# Open              218
# High              218
# Low               218
# Close               0
# BTC Volume        218
# USD Volume        218
# Weighted Price    218
# dtype: int64

# %% [markdown]
# #### Null assessment of bitstamp DataFrame
# Only 218 records out of 129540 records have null values. Since the number of such records is very small, these records will be dropped.

# %%
# drop null values out of bitstamp dataFrame
coinbase = coinbase.dropna()
# confirm null records have been dropped
coinbase.isnull().sum()
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %%
# examine coinbase DataFrame data types
coinbase.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close              object
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ##### Close column is not numeric.  It contains a `$` character.

# %%
# Use the str.replace function to remove the dollar sign, $
coinbase.loc[:, "Close"] = coinbase.loc[:, "Close"].str.replace("$", "")
# confirm that 4 was removed
coinbase.head()
# Out:
# /Users/martinsmith/opt/anaconda3/envs/cryptage/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# ...

# %%
# Convert the Close data type to a float
coinbase.loc[:, "Close"] = coinbase.loc[:, "Close"].astype("float")
# confirm type of Close changed to float
coinbase.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %%
# Review the data for duplicate values, and drop them if necessary
coinbase.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### There are no duplicated records to remove from the coinbase DataFrame.

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame
bitstamp_sliced = bitstamp.loc[:,['Close']]

# Review the first five rows of the DataFrame
bitstamp_sliced.head()
# Out:
#                         Close
# Timestamp
# 2018-01-01 00:00:00  13646.48
# 2018-01-01 00:01:00  13658.75
# 2018-01-01 00:02:00  13610.22
# 2018-01-01 00:03:00  13639.09
# 2018-01-01 00:04:00  13620.00

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame
coinbase_sliced = coinbase.loc[:,['Close']]

# Review the first five rows of the DataFrame
coinbase_sliced.head()
# Out:
#                         Close
# Timestamp
# 2018-01-01 00:00:00  13608.49
# 2018-01-01 00:01:00  13601.66
# 2018-01-01 00:02:00  13580.00
# 2018-01-01 00:03:00  13550.34
# 2018-01-01 00:04:00  13583.44

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
bitstamp_sliced.describe()
# Out:
#                Close
# count  129067.000000
# mean    10459.842453
# std      2315.976088
# min      5944.000000
# 25%      8613.370000
# 50%     10145.950000
# 75%     11444.810000
# max     17234.980000

# %%
# Generate the summary statistics for the coinbase DataFrame
coinbase_sliced.describe()
# Out:
#                Close
# count  129322.000000
# mean    10449.140958
# std      2317.197419
# min      5882.310000
# 25%      8609.230000
# 50%     10137.440000
# 75%     11397.237500
# max     17177.990000

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
bitstamp_sliced.plot(
    figsize=(15,7), 
    title="Bitstamp Bitcoin Prices - 2018 Q1", 
    color="blue")
# Out:
# <AxesSubplot:title={'center':'Bitstamp Bitcoin Prices - 2018 Q1'}, xlabel='Timestamp'>

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
coinbase_sliced.plot(
    figsize=(15,7), 
    title="Coinbase Bitcoin Prices - 2018 Q1", 
    color="orange")
# Out:
# <AxesSubplot:title={'center':'Coinbase Bitcoin Prices - 2018 Q1'}, xlabel='Timestamp'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
bitstamp_sliced['Close'].plot(color="blue",
                              label="bitstamp",
                              legend=True,
                              figsize=(15,7),
                              title="Bitcoin Prices - Bitstamp vs Coinbase - 2018 Q1")
coinbase_sliced['Close'].plot(color="orange",
                              label="coinbase",
                              legend=True,
                              figsize=(15,7))
# Out:
# <AxesSubplot:title={'center':'Bitcoin Prices - Bitstamp vs Coinbase - 2018 Q1'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
bitstamp_sliced['Close'].loc['2018-01-01':'2018-01-31'].plot(color="blue",
          label="bitstamp",
          legend=True,
          figsize=(15,7),
          title="Bitcoin Prices - Bitstamp vs Coinbase - Jan 2018")
coinbase_sliced['Close'].loc['2018-01-01':'2018-01-31'].plot(color="orange",
          label="coinbase",
          legend=True,
          figsize=(15,7))
# Out:
# <AxesSubplot:title={'center':'Bitcoin Prices - Bitstamp vs Coinbase - Jan 2018'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label 
bitstamp_sliced['Close'].loc['2018-03-01':'2018-03-31'].plot(color="blue",
          label="bitstamp",
          legend=True,
          figsize=(15,7),
          title="Bitcoin Prices - Bitstamp vs Coinbase - Mar 2018")
coinbase_sliced['Close'].loc['2018-03-01':'2018-03-31'].plot(color="orange",
          label="coinbase",
          legend=True,
          figsize=(15,7))
# Out:
# <AxesSubplot:title={'center':'Bitcoin Prices - Bitstamp vs Coinbase - Mar 2018'}, xlabel='Timestamp'>

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer** Comparing the plot of January 2018 to the plot of March 2018, it appears that the degree of spread was slightly more pronounced in January 2018 than in March 2018.  The degree of spread appears to reduce as time progressed.  Overall, the spread appears to be minimal between the exchanges.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# set up the dates to analyze as variables to make it easier to explore other days
early_date='2018-01-29'
middle_date='2018-02-24'
late_date='2018-03-24'

def plot_overlapping_series(bitstamp,coinbase,date,title):
    #bitstamp_sliced['Close']
    #f"Bitcoin Prices - Bitstamp vs Coinbase - {early_date}")
    bitstamp.loc[date].plot(color="blue",
          label="bitstamp",
          legend=True,
          figsize=(15,7),
          title=title)
    coinbase.loc[date].plot(color="orange",
          label="coinbase",
          legend=True,
          figsize=(15,7))

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
plot_overlapping_series(bitstamp_sliced['Close'],
                        coinbase_sliced['Close'],
                        early_date,
                        f"Bitcoin Prices - Bitstamp vs Coinbase - {early_date}")

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_early = bitstamp_sliced['Close'].loc[early_date] - coinbase_sliced['Close'].loc[early_date]
# Generate summary statistics for the early DataFrame
display(arbitrage_spread_early.describe())
# Out:
# count    1430.000000
# mean      120.214510
# std        85.164846
# min       -48.010000
# 25%        37.002500
# 50%       132.420000
# 75%       203.237500
# max       300.270000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
arbitrage_spread_early.plot(
    kind="box",
    title=f"Bitcoin Arbitrage Spread - Bitstamp vs Coinbase - {early_date}")
# Out:
# <AxesSubplot:title={'center':'Bitcoin Arbitrage Spread - Bitstamp vs Coinbase - 2018-01-29'}>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
plot_overlapping_series(bitstamp_sliced['Close'],
                        coinbase_sliced['Close'],
                        middle_date,
                        f"Bitcoin Prices - Bitstamp vs Coinbase - {middle_date}")

# %%
# Using the date in the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_middle = coinbase_sliced['Close'].loc[middle_date] - bitstamp_sliced['Close'].loc[middle_date]
# Generate summary statistics 
arbitrage_spread_middle.describe()
# Out:
# count    1437.000000
# mean        3.396131
# std        22.969472
# min       -50.180000
# 25%       -10.590000
# 50%        -0.010000
# 75%        12.120000
# max       121.320000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
arbitrage_spread_middle.plot(
    kind="box",
    title=f"Bitcoin Arbitrage Spread - Bitstamp vs Coinbase - {middle_date}")
# Out:
# <AxesSubplot:title={'center':'Bitcoin Arbitrage Spread - Bitstamp vs Coinbase - 2018-02-24'}>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
plot_overlapping_series(bitstamp_sliced['Close'],
                        coinbase_sliced['Close'],
                        late_date,
                        f"Bitcoin Prices - Bitstamp vs Coinbase - {late_date}")

# %%
# Using the date from the late that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_late = bitstamp_sliced['Close'].loc[late_date] - coinbase_sliced['Close'].loc[late_date]
# Generate summary statistics for the late DataFrame
arbitrage_spread_late.describe()
# Out:
# count    1410.000000
# mean        4.575277
# std         9.178928
# min       -34.010000
# 25%        -0.860000
# 50%         4.910000
# 75%        10.790000
# max        59.360000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
arbitrage_spread_middle.plot(
    kind="box",
    title=f"Bitcoin Arbitrage Spread - Bitstamp vs Coinbase - {late_date}")
# Out:
# <AxesSubplot:title={'center':'Bitcoin Arbitrage Spread - Bitstamp vs Coinbase - 2018-03-24'}>

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_early = bitstamp_sliced['Close'].loc[early_date] - coinbase_sliced['Close'].loc[early_date]

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
arbitrage_spread_early[arbitrage_spread_early>0].describe()
# Out:
# count    1379.000000
# mean      124.976425
# std        82.959829
# min         0.570000
# 25%        41.885000
# 50%       144.380000
# 75%       204.135000
# max       300.270000
# Name: Close, dtype: float64

# %%
# For one day from the middle of the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_middle = coinbase_sliced['Close'].loc[middle_date] - bitstamp_sliced['Close'].loc[middle_date]

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
arbitrage_spread_middle[arbitrage_spread_middle>0].describe()
# Out:
# count    713.000000
# mean      19.880351
# std       20.699851
# min        0.010000
# 25%        5.040000
# 50%       12.330000
# 75%       27.250000
# max      121.320000
# Name: Close, dtype: float64

# %%
# For one day late in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_late = coinbase_sliced['Close'].loc[late_date] - bitstamp_sliced['Close'].loc[late_date]

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
arbitrage_spread_late[arbitrage_spread_late>0].describe()
# Out:
# count    406.000000
# mean       6.133842
# std        5.927824
# min        0.010000
# 25%        1.880000
# 50%        4.530000
# 75%        8.417500
# max       34.010000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_early= arbitrage_spread_early[arbitrage_spread_early>0] / coinbase_sliced['Close'].loc[early_date]

# Review the spread return DataFrame
spread_return_early.describe()
# Out:
# count    1379.000000
# mean        0.011298
# std         0.007512
# min         0.000052
# 25%         0.003790
# 50%         0.013063
# 75%         0.018445
# max         0.027075
# Name: Close, dtype: float64

# %%
spread_return_early.plot(kind='box', title='Spread Return - Early')
# Out:
# <AxesSubplot:title={'center':'Spread Return - Early'}>

# %% [markdown]
# #### Observation:
# The descriptive statistics and box plot for the selected day **early** in the dataset reflect a mean of 1.13% and a median of 1.31%.  This indicates that there were a significant amount of spread returns above 1%, and potentially profitable, on that day.

# %%
# For the date from the middle of the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_middle= arbitrage_spread_middle[arbitrage_spread_middle>0] / bitstamp_sliced['Close'].loc[middle_date]

# Review the spread return DataFrame
spread_return_middle.describe()
# Out:
# count    713.000000
# mean       0.002048
# std        0.002133
# min        0.000001
# 25%        0.000524
# 50%        0.001280
# 75%        0.002820
# max        0.012726
# Name: Close, dtype: float64

# %%
spread_return_middle.plot(kind='box', title='Spread Return - Middle')
# Out:
# <AxesSubplot:title={'center':'Spread Return - Middle'}>

# %% [markdown]
# #### Observation:
# Based on the above boxplot and descriptive statistics, the spread returns for the selected day in the **middle** of dataset were mostly below 0.3%, with a few outliers above 1%.  There were just a few profitable arbitrage opportunity on this day.

# %%
# For the date late in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_late= arbitrage_spread_late[arbitrage_spread_late>0] / coinbase_sliced['Close'].loc[late_date]

# Review the spread return DataFrame
spread_return_late.describe()
# Out:
# count    406.000000
# mean       0.000697
# std        0.000677
# min        0.000001
# 25%        0.000215
# 50%        0.000508
# 75%        0.000951
# max        0.003905
# Name: Close, dtype: float64

# %%
spread_return_late.plot(kind='box', title='Spread Return - Late')
# Out:
# <AxesSubplot:title={'center':'Spread Return - Late'}>

# %% [markdown]
# #### Observation:
# Based on the above boxplot and descriptive statistics, the spread returns for the selected day **late** in the dataset were mostly below 0.1%, with no return above 1%.  There no profitable arbitrage opportunities on this day.

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
profitable_trades_early = spread_return_early[spread_return_early>0.01]
# Review the first five profitable trades
profitable_trades_early.head()
# Out:
# Timestamp
# 2018-01-29 00:00:00    0.017925
# 2018-01-29 00:01:00    0.019284
# 2018-01-29 00:02:00    0.019307
# 2018-01-29 00:03:00    0.019840
# 2018-01-29 00:04:00    0.018541
# Name: Close, dtype: float64

# %% [markdown]
# #### Observation:
# In the prior section, the descriptive statistics and box plot of the spread return for the selected day **early** in the dataset showed only that over half of the spread returns on that day were above 1%. This is indeed reflected in the *profitable_trades_early* distribution, showing several instances on this day where there were profitable arbitrage opportunities.

# %%
# For the date from the middle of the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
profitable_trades_middle = spread_return_middle[spread_return_middle>0.01]
# Review the first five profitable trades
profitable_trades_middle.head()
# Out:
# Timestamp
# 2018-02-24 08:32:00    0.012726
# 2018-02-24 09:32:00    0.010974
# 2018-02-24 09:39:00    0.010431
# Name: Close, dtype: float64

# %% [markdown]
# #### Observation:
# In the prior section, the descriptive statistics and box plot of the spread return for the selected day in the **middle** of the dataset showed only a few outliers above 1%.  This is indeed reflected in the *profitable_trades_middle* distribution showing only 3 instances on this day where there were profitable arbitrage opportunities.

# %%
# For the date late in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
profitable_trades_late = spread_return_late[spread_return_late>0.01]
# Review the first five profitable trades
profitable_trades_late.head()
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### Observation:
# In the prior section, the descriptive statistics and box plot of the spread return for the selected **late** in the dataset showed no spread returns above 1%. This is indeed reflected in the *profitable_trades_late* distribution showing only no instances on this day where there were profitable arbitrage opportunities.

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
profitable_trades_early.describe()
# Out:
# count    742.000000
# mean       0.017795
# std        0.003142
# min        0.010021
# 25%        0.015371
# 50%        0.018233
# 75%        0.020063
# max        0.027075
# Name: Close, dtype: float64

# %% [markdown]
# #### Observation:
# The above descriptive statistics of the profitable trades for the selected day **early** in the dataset reflect that many trades on that day had a sufficient amount of spread to be profitable.  With a median of 1.82%, more than half of these trades yielded a return above 1.8%

# %%
profitable_trades_middle.describe()
# Out:
# count    3.000000
# mean     0.011377
# std      0.001199
# min      0.010431
# 25%      0.010703
# 50%      0.010974
# 75%      0.011850
# max      0.012726
# Name: Close, dtype: float64

# %% [markdown]
# #### Observation:
# The above descriptive statistics of the profitable trades for the selected day in the **middle** of the dataset reflect that there were just a few profitable arbitrage opportunities on this day.  And in these cases, the spread returns were barely above the 1% threshold.

# %%
profitable_trades_late.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %% [markdown]
# #### Observation:
# As expected, from the prior analysis on the spread returns for the day **late** in the dateset, there were no trades yielding a return above 1% on this day.

# %% [markdown]
# #### How do the average returns compare among the three dates?
# The selected date **early** in the dataset has an average return of approximately 1.8% compared for nearly 0% for both the selected days in the **middle** and **late** in the dataset.

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased
profit_early = profitable_trades_early * coinbase_sliced['Close'].loc[early_date]
# Drop any missing values from the profit DataFrame
profit_per_trade_early = profit_early.dropna()
# View the early profit DataFrame
profit_per_trade_early
# Out:
# Timestamp
# 2018-01-29 00:00:00    201.98
# 2018-01-29 00:01:00    217.00
# 2018-01-29 00:02:00    217.22
# 2018-01-29 00:03:00    223.22
# 2018-01-29 00:04:00    208.64
#                         ...
# 2018-01-29 12:24:00    116.54
# 2018-01-29 12:31:00    128.44
# 2018-01-29 12:33:00    121.93
# 2018-01-29 12:37:00    111.42
# 2018-01-29 12:39:00    112.75
# Name: Close, Length: 742, dtype: float64

# %%
# For the date from the middle of the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased
profit_middle = profitable_trades_middle * coinbase_sliced['Close'].loc[middle_date]
# Drop any missing values from the profit DataFrame
profit_per_trade_middle = profit_middle.dropna()
# View the early profit DataFrame
profit_per_trade_middle
# Out:
# Timestamp
# 2018-02-24 08:32:00    122.863957
# 2018-02-24 09:32:00    108.174256
# 2018-02-24 09:39:00    102.811390
# Name: Close, dtype: float64

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased
profit_late = profitable_trades_late * coinbase_sliced['Close'].loc[late_date]
# Drop any missing values from the profit DataFrame
profit_per_trade_late = profit_late.dropna()
# View the early profit DataFrame
profit_per_trade_late
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame
profit_per_trade_early.describe()
# Out:
# count    742.000000
# mean     196.724070
# std       34.604234
# min      111.200000
# 25%      170.037500
# 50%      200.930000
# 75%      221.002500
# max      300.270000
# Name: Close, dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame
profit_per_trade_early.plot(
    color="blue",
    figsize=(15,7),
    title="Profit per Trade - Jan 29 2018"
)
# Out:
# <AxesSubplot:title={'center':'Profit per Trade - Jan 29 2018'}, xlabel='Timestamp'>

# %%
# Generate the summary statistics for the middle profit per trade DataFrame
profit_per_trade_middle.describe()
# Out:
# count      3.000000
# mean     111.283201
# std       10.381499
# min      102.811390
# 25%      105.492823
# 50%      108.174256
# 75%      115.519107
# max      122.863957
# Name: Close, dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame
profit_per_trade_middle.plot(
    color="blue",
    figsize=(15,7),
    title="Profit per Trade - Feb 24 2018"
)
# Out:
# <AxesSubplot:title={'center':'Profit per Trade - Feb 24 2018'}, xlabel='Timestamp'>

# %%
# Generate the summary statistics for the late profit per trade DataFrame
profit_per_trade_late.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame
profit_per_trade_late.plot(
    color="blue",
    figsize=(15,7),
    title="Profit per Trade - Mar 24 2018"
)
# Out:
# <AxesSubplot:title={'center':'Profit per Trade - Mar 24 2018'}, xlabel='Timestamp'>

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
profit_per_trade_early.sum()
# Out:
# 145969.25999999995

# %%
profit_per_trade_middle.sum()
# Out:
# 333.8496033506824

# %%
profit_per_trade_late.sum()
# Out:
# 0.0

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame
cumulative_profit_early = profit_per_trade_early.cumsum()

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
cumulative_profit_early.plot(
    color="blue",
    title="Cumulative Sum of Profit per Trade - Jan 29 2018" ,
    figsize=(15,7)
    )
# Out:
# <AxesSubplot:title={'center':'Cumulative Sum of Profit per Trade - Jan 29 2018'}, xlabel='Timestamp'>

# %%
# Use the cumsum function to calculate the cumulative profits over time for the middle profit per trade DataFrame
cumulative_profit_middle = profit_per_trade_middle.cumsum()

# %%
# Plot the cumulative sum of profits for the middle profit per trade DataFrame
cumulative_profit_middle.plot(
    color="blue",
    title="Cumulative Sum of Profit per Trade - Feb 24 2018",
    figsize=(15,7)
    )
# Out:
# <AxesSubplot:title={'center':'Cumulative Sum of Profit per Trade - Feb 24 2018'}, xlabel='Timestamp'>

# %%
# Use the cumsum function to calculate the cumulative profits over time for the late profit per trade DataFrame
cumulative_profit_late = profit_per_trade_late.cumsum()

# %%
# Plot the cumulative sum of profits for the late profit per trade DataFrame
cumulative_profit_late.plot(
    color="blue",
    title="Cumulative Sum of Profit per Trade - Mar 24 2018",
    figsize=(15,7)
    )
# Out:
# <AxesSubplot:title={'center':'Cumulative Sum of Profit per Trade - Mar 24 2018'}, xlabel='Timestamp'>

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** Of the three time periods, the only time period returned significant profit, the date **early** in the dataset.  This seems to indicate that the arbitrage opportunity was short lived.  Over time, the exchanges trended towards the same Bitcoin close price, leaving very little opportunity for arbitrage profit.
